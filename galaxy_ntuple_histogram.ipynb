# %%
import numpy as np
# %matplotlib nbagg
import matplotlib
import matplotlib.pyplot as plt
import tdegbviz

# %%
plt.close()

data_path = 'results/third_production_runs/v7/'
save_path = data_path

b = tdegbviz.Binner(data_path= data_path,save_path = save_path)
print('ready')
# Out:
# ready

# %%
hist_type = 'gals'
axis = 'log_mbh_sigma'

b.set_data_path('results/third_production_runs/v6/')
b.set_save_path(data_path)

b.set_hist_type(hist_type)

plt.close()
hist = b.plot_1d_histogram(axis)
plt.setp(hist,edgecolor = 'k',linewidth=1) # can change other parameters here

plt.xlabel(r'$log_{10}(M_{\rm BH}/M_\odot)$')

#plt.xlim(3,9)
#plt.ylim(0,100000)

#b.save_current_histogram()
# Out:
# Total counts is 6092542.000000
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, '$log_{10}(M_{\\rm BH}/M_\\odot)$')

# %%
hist_type = 'flares'
axis = 'log_mbh_sigma'
b.set_data_path('results/third_production_runs/v6/')
b.set_save_path(data_path)


b.set_hist_type(hist_type)
plt.close()
hist = b.plot_1d_histogram(axis) 
plt.setp(hist,edgecolor = 'k') # can change other parameters here

plt.xlabel(r'$log_{10}(M_{\rm BH}/M_\odot)$')

#plt.xlim(3,9)
#plt.ylim(0,100000)

#b.save_current_histogram()
# Out:
# Total counts is 0.227963
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, '$log_{10}(M_{\\rm BH}/M_\\odot)$')

# %%
hist_type = 'vol_disrupt'
contour_type = 'flares'
a1 = 'UminusR'
a2 = 'mstar_mendel'
b.set_data_path('results/third_production_runs/v7/')
cmap_name = 'gist_stern'
truncate_colors_max = 1.


########

b.set_save_path(data_path)
b.set_hist_type(hist_type)

# make the pcolor plot
plt.close()
b.read_2d_histogram(axis1 = a1,axis2 = a2,transpose_default = 0)
hist2d, cbar = b.plot_2d_histogram(cmap_name = cmap_name, cm_maxval = truncate_colors_max)

# make the contour plot
b.set_hist_type(contour_type)
b.read_2d_histogram(axis1 = a1,axis2 = a2,transpose_default = 0)
conts = b.plot_2d_contours()

# change contour properties
for contour in conts.collections:
    plt.setp(contour,linewidth = 2,color='w')
    

# add contour labels and set their properites
fmt = {}
strs = ['10%', '30%', '50%', '70%', '90%']
for l, s in zip(conts.levels, strs):
    fmt[l] = s
plt.gca().clabel(conts, conts.levels[0:3], inline=True, fmt=fmt, fontsize=10, colors = 'w')

# change colorbar properties
cbar.set_label('new label')
cbar.ax.tick_params(labelsize=16)

# add data points
host_data = np.loadtxt("ztf_tde_host_data_popsyn.txt",skiprows=1, usecols=(1,2,3,4))
for i in range(len(host_data)):
    plt.plot(host_data[i,0],host_data[i,1],'*',markersize=15,c = plt.cm.jet(195),markeredgecolor ='k')


# change axes labels or histogram limits
plt.xlabel(r"host $M_\ast$")
plt.ylabel(r"host $u - r$")
#plt.xlim(8.5,12)
#plt.clim(0,20000)

#b.save_current_histogram()
# Out:
# Read in data from results/third_production_runs/v7/vol_disrupt_UminusR_mstar_mendel_2d.hist
# <img src="data:image/png;base64,..." width="640">
# Total counts is 641.603884
# Read in data from results/third_production_runs/v7/flares_UminusR_mstar_mendel_2d.hist
# Total counts is 0.227871
# Text(0, 0.5, 'host $u - r$')

# %%
plt.close()

prefix = './'
hist_type = 'flares'
axis1 = 'g_minus_r'
axis2 = 'A_V'
transpose_default = 0
#cmap = "YlGnBu"
cmap = "jet"
cm_maxval = 1.
cm_minval = 0.
zlim = 0

tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'flares',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#plt.ylabel("override")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Total counts is 0
# Total counts is 0.072140

# %%
plt.close()

prefix = './'
hist_type = 'flares'
axis1 = 'log_mbh_sigma'
axis2 = 'Lbol'
transpose_default = 0
#cmap = "YlGnBu"
cmap = "jet"
cm_maxval = 1.
cm_minval = 0.
zlim = 0

tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'flares',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#plt.ylabel("override")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Total counts is 0

# %%
plt.close()

prefix = './'
hist_type = 'gals'
axis1 = 'mstar_mendel'
axis2 = 'UminusR'
transpose_default = 0
cmap = "YlGnBu"
#cmap = "jet"
cm_maxval = 0.7
cm_minval = 0.
zlim = 0

tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'flares',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#plt.ylabel("override")

plt.xlim(8.5,11.5)
plt.ylim(0.75,3.5)

host_data = np.loadtxt("ztf_tde_host_data_popsyn.txt",skiprows=1, usecols=(1,2,3,4))
for i in range(len(host_data)):
    plt.plot(host_data[i,0],host_data[i,1],'*',markersize=15,c = plt.cm.jet(195),markeredgecolor ='k')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Total counts is 5325386
# Total counts is 0.179961

# %%
plt.close()

prefix = './'
hist_type = 'gals'
axis1 = 'z'
axis2 = 'log_mbh_sigma'
transpose_default = 0
#cmap = "YlGnBu"
cmap = "jet"
cm_maxval = 1.
cm_minval = 0.
zlim = 30000

tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'flares',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Total counts is 6092542
# Total counts is 0.072140

# %%
plt.close()

prefix = './'
hist_type = 'gals'
axis1 = 'UminusR'
axis2 = 'sersic_n'
transpose_default = 1
#cmap = "YlGnBu"
cmap = "jet"
cm_maxval = 1.
cm_minval = 0.
zlim = 0

tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
# Out:
# Error: check names
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-7ed245141fd3> in <module>
#      12 zlim = 0
#      13
# ---> 14 tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#      15 tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#      16
#
# ~/Dropbox/research/TDE/host_galaxies/tdegb/tdegbviz.py in plot_2d_histogram(prefix, hist_type, axis1, axis2, transpose_default, cmap, cm_maxval, cm_minval, zlim)
#     171
#     172
# --> 173     h_grid = np.loadtxt(filename,max_rows=1) # edges
#     174     v_grid = np.loadtxt(filename,skiprows=1, max_rows=1) #edges
#     175
#
# //anaconda3/envs/default_work/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# //anaconda3/envs/default_work/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# //anaconda3/envs/default_work/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: ./gals_sersic_n_UminusR_2d.hist not found.

# %%
plt.close()

prefix = './'
hist_type = 'gals'
axis1 = 'UminusR'
axis2 = 'nuker_gamma'
transpose_default = 0
#cmap = "YlGnBu"
cmap = "jet"
cm_maxval = 1.
cm_minval = 0.
zlim = 0

tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
# Out:
# Error: check names
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-54045b723190> in <module>
#      12 zlim = 0
#      13
# ---> 14 tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#      15 tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#      16
#
# ~/Dropbox/research/TDE/host_galaxies/tdegb/tdegbviz.py in plot_2d_histogram(prefix, hist_type, axis1, axis2, transpose_default, cmap, cm_maxval, cm_minval, zlim)
#     171
#     172
# --> 173     h_grid = np.loadtxt(filename,max_rows=1) # edges
#     174     v_grid = np.loadtxt(filename,skiprows=1, max_rows=1) #edges
#     175
#
# //anaconda3/envs/default_work/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# //anaconda3/envs/default_work/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# //anaconda3/envs/default_work/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: ./gals_nuker_gamma_UminusR_2d.hist not found.

# %%
plt.close()

prefix = './'
hist_type = 'gals'
axis1 = 'log_mbh_sigma'
axis2 = 'nuker_gamma'
transpose_default = 1
#cmap = "YlGnBu"
cmap = "jet"
cm_maxval = 1.
cm_minval = 0.
zlim = 60000

tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
# Out:
# Error: check names
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-f9f8cb2cfe32> in <module>
#      12 zlim = 60000
#      13
# ---> 14 tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#      15 tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#
# ~/Dropbox/research/TDE/host_galaxies/tdegb/tdegbviz.py in plot_2d_histogram(prefix, hist_type, axis1, axis2, transpose_default, cmap, cm_maxval, cm_minval, zlim)
#     171
#     172
# --> 173     h_grid = np.loadtxt(filename,max_rows=1) # edges
#     174     v_grid = np.loadtxt(filename,skiprows=1, max_rows=1) #edges
#     175
#
# //anaconda3/envs/default_work/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# //anaconda3/envs/default_work/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# //anaconda3/envs/default_work/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: ./gals_nuker_gamma_log_mbh_sigma_2d.hist not found.
