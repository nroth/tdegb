# %%
import numpy as np
# %matplotlib nbagg
import matplotlib
import matplotlib.pyplot as plt
import tdegbviz

# %%
plt.close()

prefix = './'
hist_type = 'gals'
axis = 'z'

tdegbviz.plot_1d_histogram(prefix = prefix, hist_type = hist_type, axis = axis)
# Out:
# Total counts is 6092542.000000
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()

prefix = './'
hist_type = 'gals'
axis1 = 'mstar_mendel'
axis2 = 'UminusR'
transpose_default = 0
#cmap = "YlGnBu"
cmap = "jet"
cm_maxval = 1.
cm_minval = 0.
zlim = 0

tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
#plt.ylabel("override")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Total counts is 6092542
# Total counts is 173.814234

# %%
plt.close()

prefix = './'
hist_type = 'gals'
axis1 = 'z'
axis2 = 'log_mbh_sigma'
transpose_default = 0
#cmap = "YlGnBu"
cmap = "jet"
cm_maxval = 1.
cm_minval = 0.
zlim = 35000

tdegbviz.plot_2d_histogram(prefix =prefix, hist_type = hist_type,axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
tdegbviz.plot_2d_contours(prefix =prefix, hist_type = 'vol_disrupt',axis1 = axis1, axis2 = axis2, transpose_default = transpose_default, cmap =cmap, cm_maxval = cm_maxval, cm_minval = cm_minval, zlim = zlim)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Total counts is 6092542
# Total counts is 173.814232
